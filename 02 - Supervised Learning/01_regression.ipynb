# %% [markdown]
# Regression Algorithms:
# - Linear Regression (`sklearn.linear_model`)
#     - Simple Linear Regression
#     - Multiple Linear Regression
#     - Polynomial Regression
# - Decision Tree Regression (`sklearn.tree`)
# - Random Forest Regression (`sklearn.ensemble`)
# - Support Vector Regression (`sklearn.svm`)
# - Gradient Boosting Regression (`sklearn.ensemble`)

# %% [markdown]
# Simple Linear Regression
#
# In this regression, there are two variables, i.e., one independent variable and one dependent variable. The independent variable is the input, and the dependent variable is the output.
#
# The equation of the simple linear regression is: y = mx + c
#
# This algorithms tries to find the values of m and c such that the error is minimized.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('salary_data.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.plot(x='YearsExperience', y='Salary', kind='scatter')
plt.show()

# %% [markdown]
# In this example, we don't need to preprocess the dataset as there are no missing values as well as scaling is not required. We can directly apply the regression algorithms.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x = df[['YearsExperience']] # This will always be a 2D array (DataFrame)
y = df['Salary'] # This will always be a 1D array (Series)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (24, 1) (6, 1) (24,) (6,)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

y_pred = model.predict(x_test)
print('MSE:', round(mean_squared_error(y_test, y_pred), 2))
print('MAE:', round(mean_absolute_error(y_test, y_pred), 2))
print('R2:', round(r2_score(y_test, y_pred) * 100, 2))
# Out:
# MSE: 24875090.53
# MAE: 4288.05
# R2: 95.52

# %%
plt.scatter(x_test, y_test, color='red', label='Test')
plt.plot(x_test, y_pred, color='green', label='Predicted', linewidth=2)
plt.title('Salary vs Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.text(5, 110000, f'Accuracy: {round(r2_score(y_test, y_pred) * 100, 2)}', fontsize=12)
plt.show()
